# %%
import random

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
def generate_rnd(n):
    for i in range(0,n+1):
        if i > 0:
            print "\nQuestion:",i
            x_list = []
            y_list = []
            for x in range(0,10):
                x_list.append(random.randint(0,20))
            for y in range(0,10):
                y_list.append(random.randint(-15,15))

            # print "X Values\n"
            # print x_list
            # print "\nY Values\n"
            # print y_list
            pmcc = np.corrcoef(x_list, y_list)[0,1]
            pmcc_ = str("%.1f" % pmcc)
            # print "\nCorrelation Coefficient:\n"
            # print pmcc
            # print str("%.2f" % pmcc)

            import matplotlib.pyplot as plt
            plt.scatter(x_list,y_list)
            plt.show()

            choice = raw_input("What is the PMCC to 1dp?\n")
            if choice == pmcc_:
                print "\nCorrect!"
                i+=1
            else:
                print "\nSorry, not this time. The answer was"
                print pmcc_
                i+-1
                plt.clf

# %%
generate_rnd(5)
# Out:
# Question: 1
# What is the PMCC to 1dp?
# 0.2
#
# Sorry, not this time. The answer was
# 0.5
#
# Question: 2
# What is the PMCC to 1dp?
# -0.2
#
# Sorry, not this time. The answer was
# 0.0
#
# Question: 3
# What is the PMCC to 1dp?
# 0.3
#
# Sorry, not this time. The answer was
# -0.2
#
# Question: 4
# What is the PMCC to 1dp?
# 0.1
#
# Sorry, not this time. The answer was
# -0.2
#
# Question: 5
# What is the PMCC to 1dp?
# 0.7
#
# Sorry, not this time. The answer was
# 0.6
